# %%
import numpy as np
np.random.seed(0)
x=np.array([
    [120,85,150,95],# Glucose
    [25,30,35,22] # BMI
])
#Normalize i/p's
x=x/200
y=np.array([1,0,1,0]) # Risk of Diabetes
print(x.shape)
print(y.shape)
# Out:
# (2, 4)
# (4,)
