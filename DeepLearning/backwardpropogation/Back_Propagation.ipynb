# %% [markdown]
# # 🏥 Diabetes Risk Prediction (Binary Classification)
#
# Neural Network Architecture:
#
# 2 Inputs → 3 Hidden Neurons (Sigmoid) → 1 Output (Sigmoid)
#
# Output = 1 → High Risk
# Output = 0 → Low Risk

# %%
import numpy as np

np.random.seed(0)

X=np.array([
    [120,85,150,95], #Glucode
    [25,30,35,22]    # BMI
])

#Normalize Values
X=X/200

#Output : 1=High Risk, 0=Low Risk
Y=np.array([[1,0,1,0]])

print("X Shape:",X.shape)
print("Y Shape:",Y.shape)
# Out:
# X Shape: (2, 4)
# Y Shape: (1, 4)

# %% [markdown]
# ## Sigmoid Function

# %%
def sigmoid(Z):
  return 1/(1+np.exp(-Z))

# %% [markdown]
# #Initialize Parameters

# %%
#Hidden Layer(3 neurons,2 inputs)
w1=np.random.randn(3,2)*0.1
b1=np.zeros((3,1))
#Output Layer(1 neuron,3 hidden inputs)
w2=np.random.randn(1,3)*0.1
b2=np.zeros((1,1))

# %% [markdown]
# #Forward Propagation

# %%
#Hidden Layer
z1=np.dot(w1,X)+b1
a1=sigmoid(z1)

#Output Layer
z2=np.dot(w2,a1)+b2
a2=sigmoid(z2)

print("Predicted Output:")
print(a2)
# Out:
# Predicted Output:
# [[0.50920404 0.50906064 0.50933304 0.50909873]]

# %% [markdown]
# #Loss Function
# Binary Cross Entropy

# %%
m=Y.shape[1]
loss=-np.sum(Y*np.log(a2+1e-8)+(1-Y)*np.log(1-a2+1e-8))/m
print("Loss:",loss)
# Out:
# Loss: 0.693126613708025

# %% [markdown]
# #Back Propagation
# Output Layer Gradient

# %%
dZ2=a2-Y
dW2=(1/m)*np.dot(dZ2,a1.T)
db2=(1/m)*np.sum(dZ2,axis=1,keepdims=True)

# %% [markdown]
# #Hidden Layer Gradient
#
# Sigmoid derivative:

# %%
dA1=np.dot(w2.T,dZ2)
dZ1=dA1*a1*(1-a1)

dW1=(1/m)*np.dot(dZ1,X.T)
db1=(1/m)*np.sum(dZ1,axis=1,keepdims=True)

# %% [markdown]
# # Update Parameters

# %%
learning_rate=0.5
w2-=learning_rate*dW2
b2=learning_rate*db2

w1-=learning_rate*dW1
b1-=learning_rate*db1

# %% [markdown]
# #Complete Trainng Loop

# %%
epoch=5000
for i in range(epoch):
  #Forward
  Z1=np.dot(w1,X)+b1
  A1=sigmoid(Z1)

  Z2=np.dot(w2,A1)+b2
  A2=sigmoid(Z2)
  #loss
  loss=-np.sum(Y*np.log(A2+1e-8)+(1-Y)*np.log(1-A2+1e-8))/m
  #Backward
  dZ2=A2-Y
  dW2=(1/m)*np.dot(dZ2,A1.T)
  db2=(1/m)*np.sum(dZ2,axis=1,keepdims=True)

  dA1=np.dot(w2.T,dZ2)
  dZ1=dA1*A1*(1-A1)

  dw1=(1/m)*np.dot(dZ1,X.T)
  db1=(1/m)*np.sum(dZ1,axis=1,keepdims=True)
  #Update
  w2-= 0.5*dW2
  b2-=0.5*db2
  w1-= 0.5*dW1
  b1-=0.5*db1
  if i%100==0:
    print("Epoch:",i,"Loss:",loss)
# Out:
# Epoch: 0 Loss: 0.24897366894560222
# Epoch: 100 Loss: 0.23126503894478728
# Epoch: 200 Loss: 0.20920037224168087
# Epoch: 300 Loss: 0.17870796323703175
# Epoch: 400 Loss: 0.15092525398295908
# Epoch: 500 Loss: 0.14148270671636803
# Epoch: 600 Loss: 0.1350258760451697
# Epoch: 700 Loss: 0.1289177832206801
# Epoch: 800 Loss: 0.12310138593147935
# Epoch: 900 Loss: 0.1175608971725669
# Epoch: 1000 Loss: 0.11228200231374968
# Epoch: 1100 Loss: 0.10725148658768824
# Epoch: 1200 Loss: 0.10245702193179757
# Epoch: 1300 Loss: 0.09788703852170098
# Epoch: 1400 Loss: 0.09353063651569397
# Epoch: 1500 Loss: 0.08937751922201911
# Epoch: 1600 Loss: 0.08541793940097239
# Epoch: 1700 Loss: 0.08164265464034064
# Epoch: 1800 Loss: 0.07804288952822927
# Epoch: 1900 Loss: 0.07461030316154774
# Epoch: 2000 Loss: 0.07133696094397053
# Epoch: 2100 Loss: 0.06821530987128986
# Epoch: 2200 Loss: 0.06523815666631089
# Epoch: 2300 Loss: 0.062398648247847896
# Epoch: 2400 Loss: 0.059690254115287666
# Epoch: 2500 Loss: 0.05710675030925658
# Epoch: 2600 Loss: 0.054642204674151526
# Epoch: 2700 Loss: 0.052290963202194514
# Epoch: 2800 Loss: 0.05004763728304097
# Epoch: 2900 Loss: 0.04790709171929783
# Epoch: 3000 Loss: 0.045864433397814416
# Epoch: 3100 Loss: 0.04391500053040963
# Epoch: 3200 Loss: 0.042054352396712215
# Epoch: 3300 Loss: 0.040278259536857
# Epoch: 3400 Loss: 0.03858269435359349
# Epoch: 3500 Loss: 0.03696382209252909
# Epoch: 3600 Loss: 0.03541799217625691
# Epoch: 3700 Loss: 0.03394172987342602
# Epoch: 3800 Loss: 0.03253172828776703
# Epoch: 3900 Loss: 0.03118484065496418
# Epoch: 4000 Loss: 0.029898072937318068
# Epoch: 4100 Loss: 0.028668576707554454
# Epoch: 4200 Loss: 0.027493642314071726
# Epoch: 4300 Loss: 0.026370692320487384
# Epoch: 4400 Loss: 0.025297275212669
# Epoch: 4500 Loss: 0.024271059366564374
# Epoch: 4600 Loss: 0.02328982727016069
# Epoch: 4700 Loss: 0.022351469992841228
# Epoch: 4800 Loss: 0.021453981895301913
# Epoch: 4900 Loss: 0.020595455573068116
